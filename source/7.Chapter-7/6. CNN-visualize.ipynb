# %% [markdown]
# # CNNの可視化

# %%
import sys, os
sys.path.append(os.path.abspath(os.path.join('..', 'sample')))
import numpy as np

sys.path.append(os.path.abspath(os.path.join('..', 'sample', 'ch07')))
import visualize_filter
