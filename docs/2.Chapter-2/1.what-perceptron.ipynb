# %% [markdown]
# # パーセプトロンとは

# %% [markdown]
# * 複数の信号を入力して受け取り、一つの信号を出力する
# * 入力信号は「ニューロン」から発信される
# * 受け取ったニューロンは重み(weight)を乗算し、そのすべての総和を求める
# * 総和が *ある限界値* を超えると、新たな信号を出力する
# * ある限界値は *閾値* と呼ぶ。本ではθ (シータ) と表現する

# %% [markdown]
# とあるニューロンの信号 y の条件は以下の通りとなる
# $$
#      y =
#          \begin{cases}
#              0 \quad (w_1 x_1 + w_2 x_2 \leqq \theta) \\
#              1 \quad (w_1 x_1 + w_2 x_2 > \theta) \\
#          \end{cases}
# $$
